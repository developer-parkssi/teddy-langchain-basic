# %% [markdown]
# ## 05 GPT 모델의 토큰 사용량 확인하기

# %% [markdown]
# - `get_openai_callback()`을 이용하면 질문과 답변 과정에서 사용된 전체 사용 토큰 수, 프롬프트 및 응답에 사용된 토큰 수, 총 비용을 추적해서 확인 가능

# %%
from dotenv import load_dotenv

from langchain_teddynote import logging

load_dotenv()
logging.langsmith("CH04-Models")
# Out:
# LangSmith 추적을 시작합니다.
# [프로젝트명]
# CH04-Models

# %% [markdown]
# - `with get_openai_callback()` 구문안에서 실행되는 모든 토큰 사용량/요금이 추적

# %%
from langchain.callbacks import get_openai_callback
from langchain_openai import ChatOpenAI

# 모델을 불러옵니다.
llm = ChatOpenAI(model_name="gpt-4.1-mini")

# callback을 사용하여 추적합니다.
with get_openai_callback() as cb:
    result = llm.invoke("대한민국의 수도는 어디야?")
    print(cb)
# Out:
# Tokens Used: 26
# 	Prompt Tokens: 15
# 		Prompt Tokens Cached: 0
# 	Completion Tokens: 11
# 		Reasoning Tokens: 0
# Successful Requests: 1
# Total Cost (USD): $0.0

# %%
# callback을 사용하여 추적합니다.
with get_openai_callback() as cb:
    result = llm.invoke("대한민국의 수도는 어디야?")
    result = llm.invoke("대한민국의 수도는 어디야?")
    print(f"총 사용된 토큰수: \t\t{cb.total_tokens}")
    print(f"프롬프트에 사용된 토큰수: \t{cb.prompt_tokens}")
    print(f"답변에 사용된 토큰수: \t{cb.completion_tokens}")
    print(f"호출에 청구된 금액(USD): \t${cb.total_cost}")
# Out:
# 총 사용된 토큰수: 		49
# 프롬프트에 사용된 토큰수: 	30
# 답변에 사용된 토큰수: 	19
# 호출에 청구된 금액(USD): 	$0.0
