# %% [markdown]
# ## 파워포인트 리더

# %%
from langchain_community.document_loaders import UnstructuredPowerPointLoader

# UnstructuredPowerPointLoader 생성
loader = UnstructuredPowerPointLoader("./data/sample-ppt.pptx")

# 데이터 로드
docs = loader.load()

# 로드한 문서의 개수 출력
print(len(docs))
# Out:
# 1

# %% [markdown]
# - `Unstructured`는 텍스트의 다양한 **chunks**에 대해 다양한 "elements"를 생성
# - 기본적으로 결합되어 하나의 document 로 반환하지만, `mode="elements"`를 지정함으로써 쉽게 요소들을 분리 가능

# %%
# UnstructuredPowerPointLoader 생성
loader = UnstructuredPowerPointLoader("./data/sample-ppt.pptx", mode="elements")

# 데이터 로드
docs = loader.load()

print(len(docs))
# Out:
# 17
# page_content='랭체인 한국어 튜토리얼' metadata={'source': './data/sample-ppt.pptx', 'category_depth': 0, 'file_directory': './data', 'filename': 'sample-ppt.pptx', 'last_modified': '2026-01-27T03:30:46', 'page_number': 1, 'languages': ['kor'], 'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation', 'category': 'Title', 'element_id': '784918cd25f6cbe0084401b85fe2f3d8'}
# page_content='- 테디노트 -' metadata={'source': './data/sample-ppt.pptx', 'category_depth': 1, 'file_directory': './data', 'filename': 'sample-ppt.pptx', 'last_modified': '2026-01-27T03:30:46', 'page_number': 1, 'languages': ['kor'], 'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation', 'parent_id': '784918cd25f6cbe0084401b85fe2f3d8', 'category': 'Title', 'element_id': '2c350e6967c1bb41735104c1ec79da49'}
# page_content='' metadata={'source': './data/sample-ppt.pptx', 'last_modified': '2026-01-27T03:30:46', 'page_number': 1, 'languages': ['kor'], 'file_directory': './data', 'filename': 'sample-ppt.pptx', 'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation', 'category': 'PageBreak', 'element_id': 'bb6e0f8113091a73e55f4ff4d2ae148a'}
# page_content='Semantic Search' metadata={'source': './data/sample-ppt.pptx', 'category_depth': 0, 'file_directory': './data', 'filename': 'sample-ppt.pptx', 'last_modified': '2026-01-27T03:30:46', 'page_number': 2, 'languages': ['kor'], 'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation', 'category': 'Title', 'element_id': '6e8b7575a794927a6b843debf01ce1b7'}
# page_content='정의: 의미론적 검색은 사용자의 질의를 단순한 키워드 매칭을 넘어서 그 의미를 파악하여 관련된 결과를 반환하는 검색 방식입니다.' metadata={'source': './data/sample-ppt.pptx', 'category_depth': 0, 'file_directory': './data', 'filename': 'sample-ppt.pptx', 'last_modified': '2026-01-27T03:30:46', 'page_number': 2, 'languages': ['kor'], 'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation', 'parent_id': '6e8b7575a794927a6b843debf01ce1b7', 'category': 'UncategorizedText', 'element_id': '3ff210d258e825d62573ca4cba090279'}
# page_content='예시: 사용자가 "태양계 행성"이라고 검색하면, "목성", "화성" 등과 같이 관련된 행성에 대한 정보를 반환합니다.' metadata={'source': './data/sample-ppt.pptx', 'category_depth': 0, 'file_directory': './data', 'filename': 'sample-ppt.pptx', 'last_modified': '2026-01-27T03:30:46', 'page_number': 2, 'languages': ['kor'], 'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation', 'parent_id': '6e8b7575a794927a6b843debf01ce1b7', 'category': 'UncategorizedText', 'element_id': 'f3b323b0e57e6db3b67abdbbdb02ee0c'}
# page_content='연관키워드: 자연어 처리, 검색 알고리즘, 데이터 마이닝' metadata={'source': './data/sample-ppt.pptx', 'category_depth': 1, 'file_directory': './data', 'filename': 'sample-ppt.pptx', 'last_modified': '2026-01-27T03:30:46', 'page_number': 2, 'languages': ['kor'], 'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation', 'parent_id': '6e8b7575a794927a6b843debf01ce1b7', 'category': 'Title', 'element_id': '614192ef795ec1520268b43516f5be7f'}
# page_content='' metadata={'source': './data/sample-ppt.pptx', 'last_modified': '2026-01-27T03:30:46', 'page_number': 2, 'languages': ['kor'], 'file_directory': './data', 'filename': 'sample-ppt.pptx', 'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation', 'category': 'PageBreak', 'element_id': 'c51a83c447ad4181961a389f82653022'}
# page_content='Embedding' metadata={'source': './data/sample-ppt.pptx', 'category_depth': 0, 'file_directory': './data', 'filename': 'sample-ppt.pptx', 'last_modified': '2026-01-27T03:30:46', 'page_number': 3, 'languages': ['kor'], 'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation', 'category': 'Title', 'element_id': 'fbef5f2002a43bb7bd495745e54a3f6b'}
# page_content='정의: 임베딩은 단어나 문장 같은 텍스트 데이터를 저차원의 연속적인 벡터로 변환하는 과정입니다. 이를 통해 컴퓨터가 텍스트를 이해하고 처리할 수 있게 합니다.' metadata={'source': './data/sample-ppt.pptx', 'category_depth': 0, 'file_directory': './data', 'filename': 'sample-ppt.pptx', 'last_modified': '2026-01-27T03:30:46', 'page_number': 3, 'languages': ['kor'], 'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation', 'parent_id': 'fbef5f2002a43bb7bd495745e54a3f6b', 'category': 'NarrativeText', 'element_id': 'b4325404ef55c47cfa432e982d357a2d'}
# page_content='예시: "사과"라는 단어를 [0.65, -0.23, 0.17]과 같은 벡터로 표현합니다.' metadata={'source': './data/sample-ppt.pptx', 'category_depth': 0, 'file_directory': './data', 'filename': 'sample-ppt.pptx', 'last_modified': '2026-01-27T03:30:46', 'page_number': 3, 'languages': ['kor'], 'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation', 'parent_id': 'fbef5f2002a43bb7bd495745e54a3f6b', 'category': 'UncategorizedText', 'element_id': '5c7aee7a8ab38882f4ce17422104ae82'}
# page_content='연관키워드: 자연어 처리, 벡터화, 딥러닝 ' metadata={'source': './data/sample-ppt.pptx', 'category_depth': 1, 'file_directory': './data', 'filename': 'sample-ppt.pptx', 'last_modified': '2026-01-27T03:30:46', 'page_number': 3, 'languages': ['kor'], 'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation', 'parent_id': 'fbef5f2002a43bb7bd495745e54a3f6b', 'category': 'Title', 'element_id': 'ed9011b5100ca0fdf628149cf18c6040'}
# page_content='' metadata={'source': './data/sample-ppt.pptx', 'last_modified': '2026-01-27T03:30:46', 'page_number': 3, 'languages': ['kor'], 'file_directory': './data', 'filename': 'sample-ppt.pptx', 'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation', 'category': 'PageBreak', 'element_id': '7f8fea5b3ef4ba463a423b385f4eb7eb'}
# page_content='Token' metadata={'source': './data/sample-ppt.pptx', 'category_depth': 0, 'file_directory': './data', 'filename': 'sample-ppt.pptx', 'last_modified': '2026-01-27T03:30:46', 'page_number': 4, 'languages': ['kor'], 'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation', 'category': 'Title', 'element_id': '5bc6cd082dbaf4df50f8995797c151d4'}
# page_content='정의: 토큰은 텍스트를 더 작은 단위로 분할하는 것을 의미합니다. 이는 일반적으로 단어, 문장, 또는 구절일 수 있습니다.' metadata={'source': './data/sample-ppt.pptx', 'category_depth': 0, 'file_directory': './data', 'filename': 'sample-ppt.pptx', 'last_modified': '2026-01-27T03:30:46', 'page_number': 4, 'languages': ['kor'], 'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation', 'parent_id': '5bc6cd082dbaf4df50f8995797c151d4', 'category': 'NarrativeText', 'element_id': 'd2438047b5a87a6697f69573c291f32b'}
# page_content='예시: 문장 "나는 학교에 간다"를 "나는", "학교에", "간다"로 분할합니다.' metadata={'source': './data/sample-ppt.pptx', 'category_depth': 0, 'file_directory': './data', 'filename': 'sample-ppt.pptx', 'last_modified': '2026-01-27T03:30:46', 'page_number': 4, 'languages': ['kor'], 'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation', 'parent_id': '5bc6cd082dbaf4df50f8995797c151d4', 'category': 'NarrativeText', 'element_id': 'f40a23430d096a49f549b7edc76f4bd5'}
# page_content='연관키워드: 토큰화, 자연어 처리, 구문 분석' metadata={'source': './data/sample-ppt.pptx', 'category_depth': 1, 'file_directory': './data', 'filename': 'sample-ppt.pptx', 'last_modified': '2026-01-27T03:30:46', 'page_number': 4, 'languages': ['kor'], 'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation', 'parent_id': '5bc6cd082dbaf4df50f8995797c151d4', 'category': 'Title', 'element_id': '116d475ce699aebcc412ccda7ae4e87d'}

# %%
docs[0].metadata
# Out:
# {'source': './data/sample-ppt.pptx',
#  'category_depth': 0,
#  'file_directory': './data',
#  'filename': 'sample-ppt.pptx',
#  'last_modified': '2026-01-27T03:30:46',
#  'page_number': 1,
#  'languages': ['kor'],
#  'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#  'category': 'Title',
#  'element_id': '784918cd25f6cbe0084401b85fe2f3d8'}
